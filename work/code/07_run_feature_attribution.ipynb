# %%
# !cd "/content/drive/MyDrive/CUHK_Stuff/AI-for-Business-Research/Assignment/Final Project/Study2/code" && python 07_feature_attribution.py
# Out:
# ...
# 1D-CNN FEATURE ATTRIBUTION ANALYSIS
# ...
# Model loaded: 47 features, 22501 test samples
# Feature names: 47
#
# --- Permutation Importance ---
# Computing permutation importance...
#   Baseline AUC-ROC: 0.6347
#   [10/47] features done
#   [20/47] features done
#   [30/47] features done
#   [40/47] features done
#   Permutation importance plot saved: /content/drive/.shortcut-targets-by-id/1KKOoZevY1ahDrKYLLQ-dQDM6ItZ8AsDk/Final Project/Study2/output/figures/permutation_importance_1dcnn.png
#
#   Top-10 by Permutation Importance:
#     1. payment_method_Crypto: 0.127605 (+/- 0.005305)
#     2. device_type_Desktop: 0.074532 (+/- 0.004474)
#     3. gender_Other: 0.073323 (+/- 0.004387)
#     4. device_type_Mobile: 0.071659 (+/- 0.004921)
#     5. gender_Male: 0.068926 (+/- 0.004792)
#     6. gender_Female: 0.068503 (+/- 0.003928)
#     7. device_type_Tablet: 0.066939 (+/- 0.002923)
#     8. discount_applied: 0.052946 (+/- 0.002800)
#     9. country_India: 0.049976 (+/- 0.004214)
# ...

# %%
# !cd "/content/drive/MyDrive/CUHK_Stuff/AI-for-Business-Research/Assignment/Final Project/Study2/code" && python 08_shap_visualization.py
# Out:
# ...
# SHAP ANALYSIS FOR 1D-CNN
# ...
# Model loaded. Test set: 22501 samples, 47 features
#
# Background samples: 100
# Explain samples: 500
#
# Computing SHAP values (this may take a few minutes)...
# PermutationExplainer explainer: 501it [01:46,  4.33it/s]
# SHAP values shape: (500, 47)
# Base value: 0.0432
#
# Generating SHAP beeswarm plot...
#   Saved: /content/drive/.shortcut-targets-by-id/1KKOoZevY1ahDrKYLLQ-dQDM6ItZ8AsDk/Final Project/Study2/output/figures/shap_beeswarm_1dcnn.png
# Generating SHAP bar plot...
#   Saved: /content/drive/.shortcut-targets-by-id/1KKOoZevY1ahDrKYLLQ-dQDM6ItZ8AsDk/Final Project/Study2/output/figures/shap_bar_1dcnn.png
#   SHAP values saved: /content/drive/.shortcut-targets-by-id/1KKOoZevY1ahDrKYLLQ-dQDM6ItZ8AsDk/Final Project/Study2/output/tables/shap_values_1dcnn.json
#
# Top-15 features by mean |SHAP|:
#    1. gender_Male: 0.137148
#    2. device_type_Desktop: 0.134952
#    3. device_type_Mobile: 0.125922
#    4. gender_Other: 0.123152
# ...
